# %%
## DATASET PERTAMA
import csv
import random
import string

# Tentukan jumlah baris data yang ingin dihasilkan
jumlah_data = 100

# Rentang nilai untuk umur dan pendapatan
umur_min, umur_max = 5, 50
pendapatan_min, pendapatan_max = 0, 500000
pekerjaan_list = ['PEJABAT LEMB.EKS.& PEMERINTAH','PENYELENGGARA NEGARA ASING','JAKSA AGUNG','TNI/POLRI (TERMASUK PENSIUNAN)','PARPOL','KELUARGA PEJABAT','PERUSAHAAN SWASTA','PERUSAHAAN SWASTA ASING','PERUSAHAAN PEMERINTAH','LAIN-LAIN','PELAJAR/MAHASISWA','IBU RUMAH TANGGA','PNS (TERMASUK PENSIUNAN )','PEGAWAI BI/BUMN/BUMD(PENSIUN)','PEGAWAI BANK','PEGAWAI MONER CHANGER','PENGAJAR & DOSEN','PENGUSAHA/ WIRASWASTA','PEDAGANG','PETANI & NELAYAN','PENGRAJIN','PROFESIONAL & KONSULTAN','PENGURUS/PEG.YYS/LEMBAGA LAIN.','ULAMA/PENDETA/PIM.ORG/KL.AGAMA','PENGURUS PARPOL','BURUH,PRT & TENAGA KEAMANAN']
range_pendapatan = [1,2,3,4,5,6,7]
trx_min,trx_max = 10,2500
nom_min,nom_max = 1000000,3000000000
sentimen_min,sentimen_max = 0,100



# Nama file CSV yang akan dibuat
nama_file = 'dataset_1.csv'

# Fungsi untuk menghasilkan nama acak
def generate_random_name(length=5):
    letters = string.ascii_letters
    return ''.join(random.choice(letters) for i in range(length))

# Fungsi untuk menghasilkan nilai kol1, kol2, kol3, kol4, kol5 dengan jumlah maksimal 12 dan kol1 >= kol2 >= kol3 >= kol4 >= kol5
def generate_kol_values():
    values = [random.randint(0, 12) for _ in range(5)]
    values = sort_descending_and_return_list(values)
    total = sum(values)
    if total > 12:
        for i in range(5):
            if total <= 12:
                break
            reduce_amount = min(values[i], total - 12)
            values[i] -= reduce_amount
            total -= reduce_amount
    return values

# Fungsi untuk mengurutkan list dari besar ke kecil
def sort_descending_and_return_list(values):
    return sorted(values, reverse=True)

# Fungsi untuk menghasilkan data acak
def generate_random_data(jumlah):
    data = []
    id_nasabah = 0
    for _ in range(jumlah):
        umur = random.randint(umur_min, umur_max)
        nama = generate_random_name()
        
        pekerjaan = random.choice(pekerjaan_list)
        pendapatan = random.choice(range_pendapatan)
        
        saldo_tab = random.randint(0, 500)*10000
        saldo_giro = random.randint(0, 400)*10000
        saldo_deposito = random.randint(0, 1000)*10000
        
        kol_values = generate_kol_values()
        kol1, kol2, kol3, kol4, kol5 = kol_values
        
        hsl = sorted(kol_values, reverse=True)
        kol1, kol2, kol3, kol4, kol5 = int(hsl[0]), int(hsl[1]), int(hsl[2]), int(hsl[3]), int(hsl[4])
        if(saldo_tab>3000000):
            kol1, kol2, kol3, kol4, kol5 = 0,0,0,0,0
        
        atm_trx = random.randint(trx_min,trx_max)
        mobile_trx = random.randint(trx_min,trx_max)
        atm_nom = random.randint(nom_min,nom_max)
        mobile_nom = random.randint(nom_min,nom_max)
        internet_trx = random.randint(trx_min,trx_max)
        internet_nom = random.randint(nom_min,nom_max)
        edc_trx = random.randint(trx_min,trx_max)
        edc_nom = random.randint(nom_min,nom_max)
        
        rtgs_trx = random.randint(trx_min,trx_max)
        rtgs_nom = random.randint(nom_min,nom_max)
        
        sknbi_trx = random.randint(trx_min,trx_max)
        sknbi_nom = random.randint(nom_min,nom_max)
        
        bifast_trx = random.randint(trx_min,trx_max)
        bifast_nom = random.randint(nom_min,nom_max)
        
        qris_trx = random.randint(trx_min,trx_max)
        qris_nom = random.randint(nom_min,nom_max)
        
        senti_neg = random.randint(sentimen_min,sentimen_max)
        senti_positif = random.randint(sentimen_min,sentimen_max)
        senti_netral =  random.randint(sentimen_min,sentimen_max)
        jml_like_1 = random.randint(sentimen_min,sentimen_max)
        jml_like_2 = random.randint(sentimen_min,sentimen_max)
        jml_like_3 = random.randint(sentimen_min,sentimen_max)
        jml_like_4 = random.randint(sentimen_min,sentimen_max)
        jml_like_5 = random.randint(sentimen_min,sentimen_max)
        jml_like_6 = random.randint(sentimen_min,sentimen_max)
        jml_like_7 = random.randint(sentimen_min,sentimen_max)
        jml_like_8 = random.randint(sentimen_min,sentimen_max)
        jml_like_9 = random.randint(sentimen_min,sentimen_max)
        jml_like_10 = random.randint(sentimen_min,sentimen_max)
        
        if(kol2>0):
            label = 'Moderate'
        elif(kol1>0):
            label = 'Potential'
        else:
            label = 'Not Potential'
        
        id_nasabah = id_nasabah + 1
        data.append([id_nasabah, nama, pekerjaan, pendapatan, umur, pendapatan,saldo_tab,saldo_giro,saldo_deposito,kol1, kol2, kol3, kol4, kol5,atm_trx,atm_nom,mobile_trx,mobile_nom,internet_trx,internet_nom,edc_trx,edc_nom,rtgs_trx,rtgs_nom,sknbi_trx,sknbi_nom,bifast_trx,bifast_nom,qris_trx,qris_nom,senti_neg,senti_positif,senti_netral,jml_like_1,jml_like_2,jml_like_3,jml_like_4,jml_like_5,jml_like_6,jml_like_7,jml_like_8,jml_like_9,jml_like_10,label])
    return data

# Data acak yang dihasilkan
data_acak = generate_random_data(jumlah_data)

# Menulis data ke file CSV
with open(nama_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    # Menulis header
    writer.writerow(['id_nasabah','nama','pekerjaan','pendapatan','umur', 'pendapatan', 'saldo_tab','saldo_giro','saldo_deposito','kol_1','kol_2','kol_3','kol_4','kol_5','atm_trx','atm_nom','mobile_trx','mobile_nom','internet_trx','internet_nom','edc_trx','edc_nom','rtgs_trx','rtgs_nom','sknbi_trx','sknbi_nom','bifast_trx','bifast_nom','qris_trx','qris_nom','senti_neg','senti_positif','senti_netral','jml_like_1','jml_like_2','jml_like_3','jml_like_4','jml_like_5','jml_like_6','jml_like_7','jml_like_8','jml_like_9','jml_like_10','label'])
    # Menulis data baris demi baris
    writer.writerows(data_acak)

print(f"File '{nama_file}' telah berhasil dibuat dengan {jumlah_data} baris data.")
# Out:
# File 'dataset_1.csv' telah berhasil dibuat dengan 100 baris data.

# %%
## DATASET 2
import csv
import random
import string

# Tentukan jumlah baris data yang ingin dihasilkan
jumlah_data = 100

# Rentang nilai untuk umur dan pendapatan
umur_min, umur_max = 5, 50
pendapatan_min, pendapatan_max = 0, 500000
pekerjaan_list = ['PEJABAT LEMB.EKS.& PEMERINTAH','PENYELENGGARA NEGARA ASING','JAKSA AGUNG','TNI/POLRI (TERMASUK PENSIUNAN)','PARPOL','KELUARGA PEJABAT','PERUSAHAAN SWASTA','PERUSAHAAN SWASTA ASING','PERUSAHAAN PEMERINTAH','LAIN-LAIN','PELAJAR/MAHASISWA','IBU RUMAH TANGGA','PNS (TERMASUK PENSIUNAN )','PEGAWAI BI/BUMN/BUMD(PENSIUN)','PEGAWAI BANK','PEGAWAI MONER CHANGER','PENGAJAR & DOSEN','PENGUSAHA/ WIRASWASTA','PEDAGANG','PETANI & NELAYAN','PENGRAJIN','PROFESIONAL & KONSULTAN','PENGURUS/PEG.YYS/LEMBAGA LAIN.','ULAMA/PENDETA/PIM.ORG/KL.AGAMA','PENGURUS PARPOL','BURUH,PRT & TENAGA KEAMANAN']
range_pendapatan = [1,2,3]
masa_kerja = [1,2,3,4]
trx_min,trx_max = 10,2500
nom_min,nom_max = 1000000,3000000000
sentimen_min,sentimen_max = 0,100


# Nama file CSV yang akan dibuat
nama_file = 'dataset_2.csv'

# Fungsi untuk menghasilkan nama acak
def generate_random_name(length=5):
    letters = string.ascii_letters
    return ''.join(random.choice(letters) for i in range(length))

# Fungsi untuk menghasilkan nilai kol1, kol2, kol3, kol4, kol5 dengan jumlah maksimal 12 dan kol1 >= kol2 >= kol3 >= kol4 >= kol5
def generate_kol_values():
    values = [random.randint(0, 100) for _ in range(5)]
    values = sort_descending_and_return_list(values)
    total = sum(values)
    if total > 100:
        for i in range(5):
            if total <= 100:
                break
            reduce_amount = min(values[i], total - 100)
            values[i] -= reduce_amount
            total -= reduce_amount
    return values

# Fungsi untuk mengurutkan list dari besar ke kecil
def sort_descending_and_return_list(values):
    return sorted(values, reverse=True)

# Fungsi untuk menghasilkan data acak
def generate_random_data(jumlah):
    data = []
    id_nasabah = 0
    for _ in range(jumlah):
        umur = random.randint(umur_min, umur_max)
        nama = generate_random_name()
        
        pekerjaan = random.choice(pekerjaan_list)
        pendapatan = random.choice(range_pendapatan)
        m_kerja = random.choice(masa_kerja)
        
        kol_values = generate_kol_values()
        kol1, kol2, kol3, kol4, kol5 = kol_values
        
        hsl = sorted(kol_values, reverse=True)
        kol1, kol2, kol3, kol4, kol5 = int(hsl[0]), int(hsl[1]), int(hsl[2]), int(hsl[3]), int(hsl[4])
        nom_kol1,nom_kol2,nom_kol3,nom_kol4,nom_kol5 = kol1*10000000,kol2*10000000,kol3*10000000,kol4*10000000,kol5*10000000
        
        senti_neg = random.randint(sentimen_min,sentimen_max)
        senti_positif = random.randint(sentimen_min,sentimen_max)
        senti_netral =  random.randint(sentimen_min,sentimen_max)
        jml_like_1 = random.randint(sentimen_min,sentimen_max)
        jml_like_2 = random.randint(sentimen_min,sentimen_max)
        jml_like_3 = random.randint(sentimen_min,sentimen_max)
        jml_like_4 = random.randint(sentimen_min,sentimen_max)
        jml_like_5 = random.randint(sentimen_min,sentimen_max)
        jml_like_6 = random.randint(sentimen_min,sentimen_max)
        jml_like_7 = random.randint(sentimen_min,sentimen_max)
        jml_like_8 = random.randint(sentimen_min,sentimen_max)
        jml_like_9 = random.randint(sentimen_min,sentimen_max)
        jml_like_10 = random.randint(sentimen_min,sentimen_max)
        
        id_nasabah = id_nasabah + 1
        data.append([id_nasabah, nama, m_kerja, pendapatan,kol1,nom_kol1,kol2,nom_kol2,kol3,nom_kol3,kol4,nom_kol4,kol5,nom_kol5,senti_neg,senti_positif,senti_netral,jml_like_1,jml_like_2,jml_like_3,jml_like_4,jml_like_5,jml_like_6,jml_like_7,jml_like_8,jml_like_9,jml_like_10])
    return data

# Data acak yang dihasilkan
data_acak = generate_random_data(jumlah_data)

# Menulis data ke file CSV
with open(nama_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    # Menulis header
    writer.writerow(['id_AO','nama', 'masa_kerja','range_pendapatan','kol1','nom_kol1','kol2','nom_kol2','kol3','nom_kol3','kol4','nom_kol4','kol5','nom_kol5','senti_neg','senti_positif','senti_netral','jml_like_1','jml_like_2','jml_like_3','jml_like_4','jml_like_5','jml_like_6','jml_like_7','jml_like_8','jml_like_9','jml_like_10'])
    # Menulis data baris demi baris
    writer.writerows(data_acak)

print(f"File '{nama_file}' telah berhasil dibuat dengan {jumlah_data} baris data.")
# Out:
# File 'dataset_2.csv' telah berhasil dibuat dengan 100 baris data.

# %%
## DATASET 3
import csv
import random
import string

# Tentukan jumlah baris data yang ingin dihasilkan
jumlah_data = 100

# Rentang nilai untuk umur dan pendapatan
umur_min, umur_max = 5, 50
pendapatan_min, pendapatan_max = 0, 500000
pekerjaan_list = ['PEJABAT LEMB.EKS.& PEMERINTAH','PENYELENGGARA NEGARA ASING','JAKSA AGUNG','TNI/POLRI (TERMASUK PENSIUNAN)','PARPOL','KELUARGA PEJABAT','PERUSAHAAN SWASTA','PERUSAHAAN SWASTA ASING','PERUSAHAAN PEMERINTAH','LAIN-LAIN','PELAJAR/MAHASISWA','IBU RUMAH TANGGA','PNS (TERMASUK PENSIUNAN )','PEGAWAI BI/BUMN/BUMD(PENSIUN)','PEGAWAI BANK','PEGAWAI MONER CHANGER','PENGAJAR & DOSEN','PENGUSAHA/ WIRASWASTA','PEDAGANG','PETANI & NELAYAN','PENGRAJIN','PROFESIONAL & KONSULTAN','PENGURUS/PEG.YYS/LEMBAGA LAIN.','ULAMA/PENDETA/PIM.ORG/KL.AGAMA','PENGURUS PARPOL','BURUH,PRT & TENAGA KEAMANAN']
range_pendapatan = [1,2,3,4,5,6,7]
trx_min,trx_max = 10,2500
nom_min,nom_max = 1000000,3000000000
sentimen_min,sentimen_max = 0,100
frek_dhn_min,frek_dhn_max = 0,12 


# Nama file CSV yang akan dibuat
nama_file = 'dataset_3.csv'

# Fungsi untuk menghasilkan nama acak
def generate_random_name(length=5):
    letters = string.ascii_letters
    return ''.join(random.choice(letters) for i in range(length))

# Fungsi untuk menghasilkan nilai kol1, kol2, kol3, kol4, kol5 dengan jumlah maksimal 12 dan kol1 >= kol2 >= kol3 >= kol4 >= kol5
def generate_kol_values():
    values = [random.randint(0, 12) for _ in range(5)]
    values = sort_descending_and_return_list(values)
    total = sum(values)
    if total > 12:
        for i in range(5):
            if total <= 12:
                break
            reduce_amount = min(values[i], total - 12)
            values[i] -= reduce_amount
            total -= reduce_amount
    return values

# Fungsi untuk mengurutkan list dari besar ke kecil
def sort_descending_and_return_list(values):
    return sorted(values, reverse=True)

# Fungsi untuk menghasilkan data acak
def generate_random_data(jumlah):
    data = []
    id_nasabah = 0
    for _ in range(jumlah):
        umur = random.randint(umur_min, umur_max)
        nama = generate_random_name()
        
        pekerjaan = random.choice(pekerjaan_list)
        pendapatan = random.choice(range_pendapatan)
        
        saldo_tab = random.randint(0, 500)*10000
        saldo_giro = random.randint(0, 400)*10000
        saldo_deposito = random.randint(0, 1000)*10000
        
        #Frekuensi Kolek BJTM
        kol_values = generate_kol_values()
        kol1, kol2, kol3, kol4, kol5 = kol_values
        
        hsl = sorted(kol_values, reverse=True)
        kol1, kol2, kol3, kol4, kol5 = int(hsl[0]), int(hsl[1]), int(hsl[2]), int(hsl[3]), int(hsl[4])
        if(saldo_tab>3000000):
            kol1, kol2, kol3, kol4, kol5 = 0,0,0,0,0
        
        #Frekuensi Kolek SLIK OJK
        kol_values = generate_kol_values()
        kolslik1, kolslik2, kolslik3, kolslik4, kolslik5 = kol_values
        
        hsl = sorted(kol_values, reverse=True)
        kolslik1, kolslik2, kolslik3, kolslik4, kolslik5 = int(hsl[0]), int(hsl[1]), int(hsl[2]), int(hsl[3]), int(hsl[4])
        if(saldo_tab>3000000):
            kolslik1, kolslik2, kolslik3, kolslik4, kolslik5 = 0,0,0,0,0
            
        frekdhn = random.randint(frek_dhn_min,frek_dhn_max)
        jml_agunan = random.randint(0,20)
        total_agunan = random.randint(0,20)*100000000
        
        atm_trx = random.randint(trx_min,trx_max)
        mobile_trx = random.randint(trx_min,trx_max)
        atm_nom = random.randint(nom_min,nom_max)
        mobile_nom = random.randint(nom_min,nom_max)
        internet_trx = random.randint(trx_min,trx_max)
        internet_nom = random.randint(nom_min,nom_max)
        edc_trx = random.randint(trx_min,trx_max)
        edc_nom = random.randint(nom_min,nom_max)
        
        rtgs_trx = random.randint(trx_min,trx_max)
        rtgs_nom = random.randint(nom_min,nom_max)
        
        sknbi_trx = random.randint(trx_min,trx_max)
        sknbi_nom = random.randint(nom_min,nom_max)
        
        bifast_trx = random.randint(trx_min,trx_max)
        bifast_nom = random.randint(nom_min,nom_max)
        
        qris_trx = random.randint(trx_min,trx_max)
        qris_nom = random.randint(nom_min,nom_max)
        
        senti_neg = random.randint(sentimen_min,sentimen_max)
        senti_positif = random.randint(sentimen_min,sentimen_max)
        senti_netral =  random.randint(sentimen_min,sentimen_max)
        jml_like_1 = random.randint(sentimen_min,sentimen_max)
        jml_like_2 = random.randint(sentimen_min,sentimen_max)
        jml_like_3 = random.randint(sentimen_min,sentimen_max)
        jml_like_4 = random.randint(sentimen_min,sentimen_max)
        jml_like_5 = random.randint(sentimen_min,sentimen_max)
        jml_like_6 = random.randint(sentimen_min,sentimen_max)
        jml_like_7 = random.randint(sentimen_min,sentimen_max)
        jml_like_8 = random.randint(sentimen_min,sentimen_max)
        jml_like_9 = random.randint(sentimen_min,sentimen_max)
        jml_like_10 = random.randint(sentimen_min,sentimen_max)
        
        listrik = random.randint(0,10)*100000 
        pdam = random.randint(0,10)*100000
        pbb = random.randint(0,10)*100000
        pkb = random.randint(0,10)*100000
        postpaid = random.randint(0,10)*100000
        pulsa = random.randint(0,10)*100000
        paytv = random.randint(0,10)*100000
        asuransi = random.randint(0,10)*100000
        
        #proses pemberian kredit lihat canva dulu
        if(kol2>0):
            label = 'Moderate'
        elif(kol1>0):
            label = 'Potential'
        else:
            label = 'Not Potential'
        
        id_nasabah = id_nasabah + 1
        data.append([id_nasabah, nama, pekerjaan, pendapatan,saldo_tab,saldo_giro,saldo_deposito,kol1, kol2, kol3, kol4, kol5,kolslik1, kolslik2, kolslik3, kolslik4, kolslik5,frekdhn,jml_agunan,total_agunan,atm_trx,atm_nom,mobile_trx,mobile_nom,internet_trx,internet_nom,edc_trx,edc_nom,rtgs_trx,rtgs_nom,sknbi_trx,sknbi_nom,bifast_trx,bifast_nom,qris_trx,qris_nom,listrik,pdam,pbb,pkb,postpaid,pulsa,paytv,asuransi,senti_neg,senti_positif,senti_netral,jml_like_1,jml_like_2,jml_like_3,jml_like_4,jml_like_5,jml_like_6,jml_like_7,jml_like_8,jml_like_9,jml_like_10,label])
    return data

# Data acak yang dihasilkan
data_acak = generate_random_data(jumlah_data)

# Menulis data ke file CSV
with open(nama_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    # Menulis header
    writer.writerow(['id_nasabah','nama','pekerjaan','pendapatan','saldo_tab','saldo_giro','saldo_deposito','kol_1','kol_2','kol_3','kol_4','kol_5','kolslik1', 'kolslik2', 'kolslik3', 'kolslik4', 'kolslik5','frekdhn','jml_agunan','total_agunan','atm_trx','atm_nom','mobile_trx','mobile_nom','internet_trx','internet_nom','edc_trx','edc_nom','rtgs_trx','rtgs_nom','sknbi_trx','sknbi_nom','bifast_trx','bifast_nom','qris_trx','qris_nom','listrik','pdam','pbb','pkb','postpaid','pulsa','paytv','asuransi','senti_neg','senti_positif','senti_netral','jml_like_1','jml_like_2','jml_like_3','jml_like_4','jml_like_5','jml_like_6','jml_like_7','jml_like_8','jml_like_9','jml_like_10','label'])
    # Menulis data baris demi baris
    writer.writerows(data_acak)

print(f"File '{nama_file}' telah berhasil dibuat dengan {jumlah_data} baris data.")
# Out:
# File 'dataset_3.csv' telah berhasil dibuat dengan 100 baris data.

# %%
## DATASET 4
import csv
import random
import string

# Tentukan jumlah baris data yang ingin dihasilkan
jumlah_data = 100

# Rentang nilai untuk umur dan pendapatan
umur_min, umur_max = 5, 50
pendapatan_min, pendapatan_max = 0, 500000
pekerjaan_list = ['PEJABAT LEMB.EKS.& PEMERINTAH','PENYELENGGARA NEGARA ASING','JAKSA AGUNG','TNI/POLRI (TERMASUK PENSIUNAN)','PARPOL','KELUARGA PEJABAT','PERUSAHAAN SWASTA','PERUSAHAAN SWASTA ASING','PERUSAHAAN PEMERINTAH','LAIN-LAIN','PELAJAR/MAHASISWA','IBU RUMAH TANGGA','PNS (TERMASUK PENSIUNAN )','PEGAWAI BI/BUMN/BUMD(PENSIUN)','PEGAWAI BANK','PEGAWAI MONER CHANGER','PENGAJAR & DOSEN','PENGUSAHA/ WIRASWASTA','PEDAGANG','PETANI & NELAYAN','PENGRAJIN','PROFESIONAL & KONSULTAN','PENGURUS/PEG.YYS/LEMBAGA LAIN.','ULAMA/PENDETA/PIM.ORG/KL.AGAMA','PENGURUS PARPOL','BURUH,PRT & TENAGA KEAMANAN']
range_pendapatan = [1,2,3,4,5,6,7]
trx_min,trx_max = 10,2500
nom_min,nom_max = 1000000,3000000000
sentimen_min,sentimen_max = 0,100
frek_dhn_min,frek_dhn_max = 0,12 


# Nama file CSV yang akan dibuat
nama_file = 'dataset_4.csv'

# Fungsi untuk menghasilkan nama acak
def generate_random_name(length=5):
    letters = string.ascii_letters
    return ''.join(random.choice(letters) for i in range(length))

# Fungsi untuk menghasilkan nilai kol1, kol2, kol3, kol4, kol5 dengan jumlah maksimal 12 dan kol1 >= kol2 >= kol3 >= kol4 >= kol5
def generate_kol_values():
    values = [random.randint(0, 12) for _ in range(5)]
    values = sort_descending_and_return_list(values)
    total = sum(values)
    if total > 12:
        for i in range(5):
            if total <= 12:
                break
            reduce_amount = min(values[i], total - 12)
            values[i] -= reduce_amount
            total -= reduce_amount
    return values

# Fungsi untuk mengurutkan list dari besar ke kecil
def sort_descending_and_return_list(values):
    return sorted(values, reverse=True)

# Fungsi untuk menghasilkan data acak
def generate_random_data(jumlah):
    data = []
    id_nasabah = 0
    for _ in range(jumlah):
        umur = random.randint(umur_min, umur_max)
        nama = generate_random_name()
        
        pekerjaan = random.choice(pekerjaan_list)
        pendapatan = random.choice(range_pendapatan)
        
        saldo_tab = random.randint(0, 500)*10000
        saldo_giro = random.randint(0, 400)*10000
        saldo_deposito = random.randint(0, 1000)*10000
        
        #Frekuensi Kolek BJTM
        kol_values = generate_kol_values()
        kol1, kol2, kol3, kol4, kol5 = kol_values
        
        hsl = sorted(kol_values, reverse=True)
        kol1, kol2, kol3, kol4, kol5 = int(hsl[0]), int(hsl[1]), int(hsl[2]), int(hsl[3]), int(hsl[4])
        if(saldo_tab>3000000):
            kol1, kol2, kol3, kol4, kol5 = 0,0,0,0,0
        
        #Frekuensi Kolek SLIK OJK
        kol_values = generate_kol_values()
        kolslik1, kolslik2, kolslik3, kolslik4, kolslik5 = kol_values
        
        hsl = sorted(kol_values, reverse=True)
        kolslik1, kolslik2, kolslik3, kolslik4, kolslik5 = int(hsl[0]), int(hsl[1]), int(hsl[2]), int(hsl[3]), int(hsl[4])
        if(saldo_tab>3000000):
            kolslik1, kolslik2, kolslik3, kolslik4, kolslik5 = 0,0,0,0,0
            
        frekdhn = random.randint(frek_dhn_min,frek_dhn_max)
        jml_agunan = random.randint(0,20)
        total_agunan = random.randint(0,20)*100000000
        
        atm_trx = random.randint(trx_min,trx_max)
        mobile_trx = random.randint(trx_min,trx_max)
        atm_nom = random.randint(nom_min,nom_max)
        mobile_nom = random.randint(nom_min,nom_max)
        internet_trx = random.randint(trx_min,trx_max)
        internet_nom = random.randint(nom_min,nom_max)
        edc_trx = random.randint(trx_min,trx_max)
        edc_nom = random.randint(nom_min,nom_max)
        
        rtgs_trx = random.randint(trx_min,trx_max)
        rtgs_nom = random.randint(nom_min,nom_max)
        
        sknbi_trx = random.randint(trx_min,trx_max)
        sknbi_nom = random.randint(nom_min,nom_max)
        
        bifast_trx = random.randint(trx_min,trx_max)
        bifast_nom = random.randint(nom_min,nom_max)
        
        qris_trx = random.randint(trx_min,trx_max)
        qris_nom = random.randint(nom_min,nom_max)
        
        senti_neg = random.randint(sentimen_min,sentimen_max)
        senti_positif = random.randint(sentimen_min,sentimen_max)
        senti_netral =  random.randint(sentimen_min,sentimen_max)
        jml_like_1 = random.randint(sentimen_min,sentimen_max)
        jml_like_2 = random.randint(sentimen_min,sentimen_max)
        jml_like_3 = random.randint(sentimen_min,sentimen_max)
        jml_like_4 = random.randint(sentimen_min,sentimen_max)
        jml_like_5 = random.randint(sentimen_min,sentimen_max)
        jml_like_6 = random.randint(sentimen_min,sentimen_max)
        jml_like_7 = random.randint(sentimen_min,sentimen_max)
        jml_like_8 = random.randint(sentimen_min,sentimen_max)
        jml_like_9 = random.randint(sentimen_min,sentimen_max)
        jml_like_10 = random.randint(sentimen_min,sentimen_max)
        
        listrik = random.randint(0,10)*100000 
        pdam = random.randint(0,10)*100000
        pbb = random.randint(0,10)*100000
        pkb = random.randint(0,10)*100000
        postpaid = random.randint(0,10)*100000
        pulsa = random.randint(0,10)*100000
        paytv = random.randint(0,10)*100000
        asuransi = random.randint(0,10)*100000
        
        #proses pemberian kredit lihat canva dulu
        if(kol2>0):
            label = 'Moderate'
        elif(kol1>0):
            label = 'Potential'
        else:
            label = 'Not Potential'
        
        id_nasabah = id_nasabah + 1
        data.append([id_nasabah, nama, pekerjaan, pendapatan,saldo_tab,saldo_giro,saldo_deposito,kol1, kol2, kol3, kol4, kol5,kolslik1, kolslik2, kolslik3, kolslik4, kolslik5,frekdhn,jml_agunan,total_agunan,atm_trx,atm_nom,mobile_trx,mobile_nom,internet_trx,internet_nom,edc_trx,edc_nom,rtgs_trx,rtgs_nom,sknbi_trx,sknbi_nom,bifast_trx,bifast_nom,qris_trx,qris_nom,listrik,pdam,pbb,pkb,postpaid,pulsa,paytv,asuransi,senti_neg,senti_positif,senti_netral,jml_like_1,jml_like_2,jml_like_3,jml_like_4,jml_like_5,jml_like_6,jml_like_7,jml_like_8,jml_like_9,jml_like_10,label])
    return data

# Data acak yang dihasilkan
data_acak = generate_random_data(jumlah_data)

# Menulis data ke file CSV
with open(nama_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    # Menulis header
    writer.writerow(['id_nasabah','nama','pekerjaan','pendapatan','saldo_tab','saldo_giro','saldo_deposito','kol_1','kol_2','kol_3','kol_4','kol_5','kolslik1', 'kolslik2', 'kolslik3', 'kolslik4', 'kolslik5','frekdhn','jml_agunan','total_agunan','atm_trx','atm_nom','mobile_trx','mobile_nom','internet_trx','internet_nom','edc_trx','edc_nom','rtgs_trx','rtgs_nom','sknbi_trx','sknbi_nom','bifast_trx','bifast_nom','qris_trx','qris_nom','listrik','pdam','pbb','pkb','postpaid','pulsa','paytv','asuransi','senti_neg','senti_positif','senti_netral','jml_like_1','jml_like_2','jml_like_3','jml_like_4','jml_like_5','jml_like_6','jml_like_7','jml_like_8','jml_like_9','jml_like_10','label'])
    # Menulis data baris demi baris
    writer.writerows(data_acak)

print(f"File '{nama_file}' telah berhasil dibuat dengan {jumlah_data} baris data.")
# Out:
# File 'dataset_4.csv' telah berhasil dibuat dengan 100 baris data.
